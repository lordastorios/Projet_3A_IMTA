# %% [markdown]
# # Data assimilation example
#
# This notebook is an example of data assimilation on eddies. It uses the file classes.py, eddy_prediction.py and plot.py of the project (https://github.com/lordastorios/Projet_3A_IMTA).
#
# Autors: G. Ghienne, **A. Lefebvre, A. Lerosey, L. Menard, A. Perier.**
#
# Note that the project use the AnDA library attached to the publication "The Analog Data Assimilation", from **R. Lguensat, P. Tandeo, and others**, submitted to the *Monthly Weather Review*.

# %% [markdown]
# ## Initialization

# %% [markdown]
# We first initialize our environnement and do usefull import

# %%
import sys
sys.path.append("../")
import warnings
warnings.filterwarnings("ignore")

from eddies_prediction import create_catalog,calculate_B,predict_eddy,get_eddy,create_observation
from plot import StreamPlot

import matplotlib.pyplot as plt
import pandas as pd
from time import time
import numpy as np

# %% [markdown]
# We now define a catalog as well as some future observation from a 'catalog.csv file' (see Eddies_path.pynb).

# %%
dt_frame_eddies = pd.read_csv("catalog.csv",usecols=list(range(1,9)))

present_time=80
catalog_eddies = dt_frame_eddies[dt_frame_eddies.date<80]
observation_eddies = dt_frame_eddies[dt_frame_eddies.date>=80]

# %%
catalog_eddies
# Out:
#      date  id   center_x   center_y         a         b     angle     omega
# 0       0   1  55.182947  15.765710  0.996490  0.917343  0.359370 -0.000003
# 1       0   2  57.663832  16.462744  0.352356  0.901428 -2.984302  0.000004
# 2       1   1  55.198971  15.686171  1.061340  0.928108  0.556703 -0.000004
# 3       1   2  57.583567  16.511366  0.392029  0.786621 -3.020211  0.000005
# 4       2   1  55.053229  15.625271  1.156326  0.942291  0.322667 -0.000004
# ..    ...  ..        ...        ...       ...       ...       ...       ...
# 161    77  11  56.577554  14.748894  0.565765  0.882141  3.135939 -0.000003
# 162    77  14  53.950322  14.728423  0.577026  1.084686 -2.848391  0.000003
# 163    78  11  56.605443  14.736110  0.581100  0.975006  3.029069 -0.000003
# 164    79  11  56.468997  14.341965  0.673645  0.767303  3.010980 -0.000004
# 165    79  14  53.924283  15.006723  0.656435  1.114929 -2.895082  0.000003
#
# [166 rows x 8 columns]

# %%
observation_eddies
# Out:
#      date  id   center_x   center_y         a         b     angle     omega
# 166    80  14  53.790971  15.325569  0.639008  0.873077 -2.951389  0.000003
# 167    80  15  58.215758  14.421795  0.377289  0.737061 -2.953219  0.000004
# 168    81  11  56.446621  14.361043  0.644958  0.786606  2.930708 -0.000004
# 169    81  14  53.756820  15.189535  0.727554  1.084137 -2.885969  0.000003
# 170    82   8  58.935352  18.788171  0.741394  0.440887  0.539677 -0.000004
# 171    82  15  58.136610  14.123371  0.539970  0.618927 -2.723295  0.000004
# 172    82  16  59.810651  17.931012  0.910706  0.351624  0.529714  0.000005
# 173    83  16  59.796192  17.893015  0.699829  0.297668  0.597690  0.000005
# 174    83   8  58.903722  18.833556  0.917175  0.597839  0.513029 -0.000004
# 175    83  15  58.140276  14.120412  0.636711  0.706848 -2.687670  0.000003
# 176    84  16  59.883461  17.825903  0.723938  0.438354  0.749022  0.000005
# 177    84   8  58.560445  18.738029  0.898621  0.473482  0.588907 -0.000004
# 178    84  14  53.559875  15.261600  0.703094  0.795418  2.790651  0.000003
# 179    84  15  58.211986  14.031271  0.624577  0.574905 -0.437113  0.000004
# 180    85  16  59.972510  18.020582  0.421417  0.806656  2.492885  0.000005
# 181    85  14  53.533067  15.387521  0.420380  0.595795  2.868366  0.000003
# 182    85  15  58.275397  14.106651  0.672592  0.530853 -0.287718  0.000004
# 183    86  16  59.931263  18.040558  0.355286  0.732727  2.578854  0.000006
# 184    86  14  53.497649  15.392956  0.505890  0.708908  2.670260  0.000003
# 185    86  15  58.068002  14.137282  0.633575  0.660599  2.719612  0.000004
# 186    87  16  59.920035  18.001134  0.404861  0.710541  2.586479  0.000006
# 187    87  14  53.462174  15.470342  0.713135  0.832916  2.885728  0.000003
# 188    88  16  59.965573  18.024443  0.418091  0.573669  2.635021  0.000006
# 189    88  14  53.444725  15.622960  0.620354  0.911026  2.525288  0.000004
# 190    89  16  59.911472  17.991510  0.436874  0.557266  2.547307  0.000006
# 191    89  11  55.906201  13.745290  0.559448  0.429146 -0.273905 -0.000004
# 192    89  14  53.462094  15.748295  0.529236  0.925537  2.423738  0.000004
# 193    90  14  53.284134  15.617644  0.511078  0.930725  2.555062  0.000004
# 194    90  16  59.939220  17.971735  0.537537  0.723114  2.454440  0.000005
# 195    91  11  55.920286  13.829934  0.614365  0.344460 -0.365892 -0.000004
# 196    91  14  53.086750  15.387723  0.486420  0.844208  2.647912  0.000004
# 197    91  15  58.030813  14.412927  0.413239  0.513580 -2.426188  0.000005
# 198    91  16  59.957995  17.877444  0.625607  0.467636  0.453443  0.000006
# 199    92  16  59.908115  17.845990  0.567108  0.382141  0.346325  0.000006
# 200    93  16  59.866519  17.755525  0.699890  0.412601  0.273888  0.000006
# 201    93  11  55.959168  13.751863  0.951263  0.373170 -0.559191 -0.000004
# 202    93  14  52.848178  15.215640  0.414368  0.796005  2.582578  0.000004
# 203    93  15  57.952454  14.434759  0.577282  0.420593 -0.733533  0.000005
# 204    94  14  52.900089  15.402453  0.325821  0.685486  2.523029  0.000004
# 205    94  15  57.915516  14.559378  0.518463  0.411842 -0.711874  0.000004
# 206    94  16  59.980426  17.762392  0.625809  0.312775  0.323339  0.000006
# 207    95  14  52.753757  15.260922  0.387449  0.756363  2.502485  0.000004
# 208    95  15  57.924187  14.547726  0.861755  0.444412 -0.578708  0.000004
# 209    96  16  59.976141  17.718584  0.695129  0.346252  0.349276  0.000005
# 210    97  14  52.692357  15.246869  0.338928  0.800629  2.397085  0.000004
# 211    97  16  60.023180  17.732535  0.629456  0.252991  0.457928  0.000005
# 212    98  15  57.600258  14.607664  0.861023  0.410847 -0.575896  0.000004

# %% [markdown]
# Let suppose we want to forecast parameters of the eddy with id=14.

# %%
catalog=create_catalog(catalog_eddies)
observation=create_observation(observation_eddies,id=14)

# %% [markdown]
# ## Data Assimilation

# %% [markdown]
# We initialize the first eddy and define a observation noise matrix (more details and possibilities are possible, do not hesitate to read the documentation).
# We can now run the data assimilation itself.

# %%
eddy=get_eddy(observation,0)

plt.rcParams['figure.figsize'] = 10, 10
figure=StreamPlot()
figure.plot_eddies([eddy])
figure.show()

# %%
R=np.eye(6)/1000 #covariance of observation noise

# %%
prediction=predict_eddy(eddy,catalog,observation,R=R)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 98.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 529.20it/s]

# %% [markdown]
# ## Results

# %%
plt.rcParams['figure.figsize'] = 3, 3
for t in prediction.time:
    i=t-present_time
    eddy=get_eddy(prediction,i)
    print("Prediction t=%s"%i)
    figure=StreamPlot()
    figure.plot_eddies([eddy])
    figure.show()
# Out:
# Prediction t=0
# Prediction t=1
# Prediction t=2
# Prediction t=3
# Prediction t=4
# Prediction t=5
# Prediction t=6
# Prediction t=7
# Prediction t=8
# Prediction t=9
# Prediction t=10
# Prediction t=11
# Prediction t=12
# Prediction t=13
# Prediction t=14
# Prediction t=15
# Prediction t=16
# Prediction t=17
# Prediction t=18

# %% [markdown]
# We can look it parameter by parameter. For example, let focus on the first axe of the ellipse.

# %%
plt.rcParams['figure.figsize'] = 7, 7
plt.plot(observation.values[:,2],'or',markersize=10,label="observations")
plt.plot(prediction.values[:,2],'-g',linewidth=3,label="predictions")
plt.xlabel("time"),plt.ylabel("ellipse axe size"),plt.legend()
plt.show()
